# %%
import importlib as ilib
import logging
import plotly.offline as plo
import time

# %%
import omega_ui.backtest as ob
import omega_ui.tearsheet as ots
import omega_ui.tests.test_backtest as ottb

plo.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Disable logging output
log = logging.getLogger()
log.setLevel(logging.WARNING)

# %% [markdown]
# # Backtest

# %%
#ilib.reload(ort)
start = time.time()
btm = ottb.ExampleBacktest()
# Parameters
symbols = ['TestData']
cash = 100000.0
# Strategy
strategy = ottb.StatsTest
pnl, results = btm.run(symbols, cash, strategy)
print('Total Profit: {:,.2f}'.format(pnl))
print('Backtest - Execution time: {:.0f} seconds!'.format(time.time() - start))
# Out:
# Buying On Bar 1 Price = 1.0
# Closing On Bar 20 Price = 101.0
# Buying On Bar 21 Price = 101.0
# Closing On Bar 40 Price = 1.0
# Buying On Bar 41 Price = 1.0
# Closing On Bar 60 Price = 101.0
# Buying On Bar 61 Price = 101.0
# Closing On Bar 80 Price = 1.0
# Total Profit: 0.00
# Backtest - Execution time: 1 seconds!

# %% [markdown]
# ## Tearsheet & Statistics

# %%
ts = ots.create_tearsheet(results, symbols)

# %%
plo.iplot(ts['fig'])
# Out:
# <div id="8c0047c3-fde1-474f-87ef-14554b95f6e2" style="height: 1200px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8c0047c3-fde1-474f-87ef-14554b95f6e2", [{"type": "scatter", "x": ["2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-09", "2018-04-10", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-16", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-21", "2018-04-22", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-28", "2018-04-29", "2018-04-30", "2018-05-01", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-05", "2018-05-06", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-11", "2018-05-12", "2018-05-13", "2018-05-14", "2018-05-15", "2018-05-16", "2018-05-17", "2018-05-18", "2018-05-19", "2018-05-20", "2018-05-21", "2018-05-22", "2018-05-23", "2018-05-24", "2018-05-25", "2018-05-26", "2018-05-27", "2018-05-28", "2018-05-29", "2018-05-30", "2018-05-31", "2018-06-01", "2018-06-02", "2018-06-03", "2018-06-04", "2018-06-05", "2018-06-06", "2018-06-07", "2018-06-08", "2018-06-09", "2018-06-10", "2018-06-11", "2018-06-12", "2018-06-13", "2018-06-14", "2018-06-15", "2018-06-16", "2018-06-17", "2018-06-18", "2018-06-19", "2018-06-20", "2018-06-21", "2018-06-22", "2018-06-23", "2018-06-24", "2018-06-25", "2018-06-26", "2018-06-27", "2018-06-28", "2018-06-29", "2018-06-30", "2018-07-01", "2018-07-02", "2018-07-03", "2018-07-04", "2018-07-05", "2018-07-06", "2018-07-07", "2018-07-08", "2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-14", "2018-07-15", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-21", "2018-07-22", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-28", "2018-07-29", "2018-07-30", "2018-07-31", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-04", "2018-08-05", "2018-08-06", "2018-08-07", "2018-08-08", "2018-08-09", "2018-08-10", "2018-08-11", "2018-08-12", "2018-08-13", "2018-08-14", "2018-08-15", "2018-08-16", "2018-08-17", "2018-08-18", "2018-08-19", "2018-08-20", "2018-08-21", "2018-08-22", "2018-08-23", "2018-08-24", "2018-08-25", "2018-08-26", "2018-08-27", "2018-08-28", "2018-08-29", "2018-08-30", "2018-08-31", "2018-09-01", "2018-09-02", "2018-09-03", "2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-09", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-16", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-21", "2018-09-22", "2018-09-23", "2018-09-24", "2018-09-25", "2018-09-26", "2018-09-27", "2018-09-28", "2018-09-29", "2018-09-30", "2018-10-01", "2018-10-02", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-12", "2018-10-13", "2018-10-14", "2018-10-15", "2018-10-16", "2018-10-17", "2018-10-18", "2018-10-19", "2018-10-20", "2018-10-21", "2018-1 ...

# %%
ts['statistics']
# Out:
# {'Curve': {'Annual Volatility': 0.02,
#   'CAGR': -0.0,
#   'Max Daily Drawdown': -0.1,
#   'Max Drawdown Duration': 1739,
#   'R-Squared': 0.09,
#   'SQN': 0.0,
#   'Sharpe Ratio': 0.0,
#   'Total Return': -0.0,
#   'Trades Per Year': 0},
#  'Time': {'Average Losing Month %': -0.1,
#   'Average Winning Month %': 0.1,
#   'Best Month %': 0.1,
#   'Best Year %': 0.0,
#   'Winning Months %': 3.28,
#   'Winning Years %': 16.67,
#   'Worst Month %': -0.1,
#   'Worst Year %': 0.0},
#  'Trade': {'Average Loss': -51.0,
#   'Average Trade': 0.0,
#   'Average Win': 51.0,
#   'Avg Days in Trade': 19.0,
#   'Best Trade': 101.0,
#   'Trade Winning %': 50.0,
#   'Trades': 8,
#   'Worst Trade': -101.0,
#   'Worst Trade Date': '2018-02-012018-04-02'}}
